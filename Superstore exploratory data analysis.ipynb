# %%
#1)Identifying and importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#2)a.Load the dataset from a file
data = pd.read_csv("Superstore.xls - Orders.csv")
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#2)b.Look at the first 5 records of the data
data.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#2)c.Print the columns contained in the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#2)d.Print the attributes like count , mean , max , min, standard deviation etc.
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#2)e.Find out if there are any missing or null values in the dataset for all columns
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#3)a.Convert date time field into pandas time object
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data['Order Date'] = pd.to_datetime(data['Order Date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#3)b. Find out the price per unit from the data and create a column for it in the same data
data['price per unit'] = data['Sales'] / data['Quantity']
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#part of task 4
data['year_month_order'] = pd.to_datetime(data['Order Date']).dt.to_period('M')
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
data['year_month_ship'] = pd.to_datetime(data['Ship Date']).dt.to_period('M')
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
data['year_month_ship'].unique()
# Out:
# <PeriodArray>
# ['2016-11', '2016-06', '2015-10', '2014-06', '2017-04', '2016-12', '2015-11',
#  '2014-11', '2014-05', '2014-09', '2017-07', '2015-09', '2016-01', '2017-10',
#  '2015-12', '2017-09', '2016-07', '2016-03', '2014-10', '2015-04', '2015-05',
#  '2014-12', '2016-09', '2017-12', '2017-11', '2017-05', '2016-04', '2015-02',
#  '2017-06', '2014-08', '2015-03', '2017-02', '2016-10', '2015-06', '2014-03',
#  '2016-05', '2015-01', '2015-08', '2018-01', '2015-07', '2014-07', '2014-04',
#  '2017-03', '2017-08', '2017-01', '2014-02', '2014-01', '2016-08', '2016-02']
# Length: 49, dtype: period[M]

# %%
data['year_month_order'].unique()
# Out:
# <PeriodArray>
# ['2016-11', '2016-06', '2015-10', '2014-06', '2017-04', '2016-12', '2015-11',
#  '2014-11', '2014-05', '2014-08', '2017-07', '2015-09', '2016-01', '2017-10',
#  '2015-12', '2017-09', '2016-07', '2016-03', '2014-10', '2015-04', '2014-12',
#  '2016-09', '2017-12', '2017-11', '2017-05', '2016-04', '2015-01', '2017-06',
#  '2016-08', '2015-03', '2014-09', '2017-02', '2016-10', '2015-05', '2014-03',
#  '2016-05', '2015-02', '2015-08', '2015-07', '2014-07', '2015-06', '2014-04',
#  '2017-03', '2017-08', '2017-01', '2014-02', '2014-01', '2016-02']
# Length: 48, dtype: period[M]

# %%
#4)a.Create a column with Year and month field only give a suitable name to it
#4)b.Create a separate dataset from the data which will have two columns, 
#one which is created in step a of this task and second the monthly sales / revenue
yearmonth_table = pd.DataFrame()
yearmonth_table['year and month'] = data['year_month_ship']
yearmonth_table['revenue'] = data['Profit']
yearmonth_table
# Out:
#      year and month   revenue
# 0           2016-11   41.9136
# 1           2016-11  219.5820
# 2           2016-06    6.8714
# 3           2015-10 -383.0310
# 4           2015-10    2.5164
# ...             ...       ...
# 9989        2014-01    4.1028
# 9990        2017-03   15.6332
# 9991        2017-03   19.3932
# 9992        2017-03   13.3200
# 9993        2017-05   72.9480
#
# [9994 rows x 2 columns]

# %%
yearmonth_table.groupby(['year and month']).mean()
# Out:
#                   revenue
# year and month
# 2014-01         33.668229
# 2014-02         17.323850
# 2014-03          0.875264
# 2014-04         24.542643
# 2014-05         20.922358
# 2014-06         40.279288
# 2014-07         -6.939730
# 2014-08         41.352581
# 2014-09         27.564055
# 2014-10         27.028257
# 2014-11         30.080980
# 2014-12         26.299312
# 2015-01        -13.995861
# 2015-02         49.354464
# 2015-03         74.526062
# 2015-04         10.673973
# 2015-05         39.453621
# 2015-06         33.477874
# 2015-07         19.733111
# 2015-08         25.527694
# 2015-09         30.150787
# 2015-10         21.567665
# 2015-11         40.268201
# 2015-12         23.362820
# 2016-01         34.805710
# 2016-02         57.329386
# 2016-03         23.987299
# 2016-04         16.181762
# 2016-05         34.546946
# 2016-06         28.599617
# 2016-07         24.126390
# 2016-08         13.308633
# 2016-09         25.502243
# 2016-10         78.146625
# ...

# %%
d = {'year_month_str': ['2014-01','2014-02', '2014-03','2014-04','2014-05','2014-06','2014-07', '2014-08','2014-09','2014-10',
                  '2014-11','2014-12','2015-01','2015-02','2015-03','2015-04','2015-05','2015-06','2015-07','2015-08',
                  '2015-09', '2015-10','2015-11', '2015-12','2016-01','2016-02','2016-03','2016-04','2016-05','2016-06',
                  '2016-07','2016-08','2016-09','2016-10','2016-11','2016-12','2017-01','2017-02','2017-03','2017-04','2017-05',
                  '2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12','2018-01'], 'revenue_str': [33.668229,17.323850,0.875264,24.542643,20.922358,40.279288,-6.939730,41.352581,27.564055,
               27.028257,30.080980,26.299312,-13.995861,49.354464,74.526062,10.673973,39.453621,33.477874,
               19.733111,25.527694,30.150787,21.567665,40.268201,23.362820,34.805710,57.329386,23.987299,
               16.181762,34.546946,28.599617,24.126390,13.308633,25.502243,78.146625,31.710132,31.758769,
               38.540655,17.440983,58.477451,13.594028,24.321069,29.609657,29.907201, 44.933889, 24.861671,
                29.918113, 19.396823, 20.131049, 22.256890]}
     
month_table = pd.DataFrame(d)

month_table.plot(x ='year_month_str', y = 'revenue_str', kind = 'line')
plt.show()
#the monthly revenue is not stable. In the year 2014, it seems that early in the year and later in the year there 
#has been a great decrease in the profit. Meanwhile, in the year 2016, in between the year there has been a sharp increase in the revenue.

# %%
#part of task 5
data['year_order'] = pd.DatetimeIndex(data['Order Date']).year
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
data['year_ship'] = pd.DatetimeIndex(data['Ship Date']).year
data.head()
data['year_ship'].unique()
# Out:
# array([2016, 2015, 2014, 2017, 2018])

# %%
data['year_order'].unique()
# Out:
# array([2016, 2015, 2014, 2017])

# %%
#5)a.Create a column with Year field only give a suitable name to it
#5)b.Create a separate dataset from the data which will have two columns , 
#one which is created in step a of this task and second the monthly sales / revenue
year_table = pd.DataFrame()
year_table['Year'] = data['year_ship']
year_table['Revenue'] = data['Profit']
year_table
# Out:
#       Year   Revenue
# 0     2016   41.9136
# 1     2016  219.5820
# 2     2016    6.8714
# 3     2015 -383.0310
# 4     2015    2.5164
# ...    ...       ...
# 9989  2014    4.1028
# 9990  2017   15.6332
# 9991  2017   19.3932
# 9992  2017   13.3200
# 9993  2017   72.9480
#
# [9994 rows x 2 columns]

# %%
year_table.groupby(['Year']).mean()
# Out:
#         Revenue
# Year
# 2014  24.377694
# 2015  29.507992
# 2016  32.172654
# 2017  27.958485
# 2018  22.256890

# %%
#5)c.Plot this dataset
x = year_table['Year']
y = year_table['Revenue']
plt.bar(x, y, color = 'Blue')
plt.bar(x, y, color = 'Blue',linewidth=5,linestyle='dashed')
plt.xlabel("revenue")
plt.ylabel("year")
plt.title("yearly revenue")
plt.show()
#in 2016 the yearly revenue was the highest while in 2018 the yearly revenue was the lowest. The increase in yearly revenue is not stable. 
#It significantly rised and significantly decreased in few years.

# %%
#6)a.Create a column in the monthly revenue dataset for monthly growth rate
growth_rate = []

for i in range(len(yearmonth_table)):
    value = ((yearmonth_table['revenue'].iloc[i] - yearmonth_table['revenue'].iloc[i-1])/yearmonth_table['revenue'].iloc[i])*100
    growth_rate.append(value)
        
yearmonth_table
# Out:
# <ipython-input-96-21b6a2432342>:5: RuntimeWarning: divide by zero encountered in double_scalars
#   value = ((yearmonth_table['revenue'].iloc[i] - yearmonth_table['revenue'].iloc[i-1])/yearmonth_table['revenue'].iloc[i])*100
# <ipython-input-96-21b6a2432342>:5: RuntimeWarning: invalid value encountered in double_scalars
#   value = ((yearmonth_table['revenue'].iloc[i] - yearmonth_table['revenue'].iloc[i-1])/yearmonth_table['revenue'].iloc[i])*100
#      year and month   revenue   growth rate
# 0           2016-11   41.9136    -74.043747
# 1           2016-11  219.5820     80.912097
# 2           2016-06    6.8714  -3095.593329
# 3           2015-10 -383.0310    101.793954
# 4           2015-10    2.5164  15321.387697
# ...             ...       ...           ...
# 9989        2014-01    4.1028  -1256.317637
# 9990        2017-03   15.6332     73.755853
# 9991        2017-03   19.3932     19.388239
# 9992        2017-03   13.3200    -45.594595
# ...

# %%
#6)b.Find out the maximum monthly growth rate
yearmonth_table.max()
# Out:
# year and month    2018-01
# revenue           8399.98
# growth rate           inf
# dtype: object

# %%
#6)c.plot this monthly growth rate
table = pd.DataFrame()
table['yearmon'] = yearmonth_table['year and month']
table['growth rate'] = yearmonth_table['growth rate']
table
# Out:
#       yearmon   growth rate
# 0     2016-11    -74.043747
# 1     2016-11     80.912097
# 2     2016-06  -3095.593329
# 3     2015-10    101.793954
# 4     2015-10  15321.387697
# ...       ...           ...
# 9989  2014-01  -1256.317637
# 9990  2017-03     73.755853
# 9991  2017-03     19.388239
# 9992  2017-03    -45.594595
# 9993  2017-05     81.740418
#
# [9994 rows x 2 columns]

# %%
table.groupby(['yearmon']).mean()
# Out:
#          growth rate
# yearmon
# 2014-01         -inf
# 2014-02  -202.806082
# 2014-03          NaN
# 2014-04         -inf
# 2014-05  -271.858001
# 2014-06          NaN
# 2014-07          NaN
# 2014-08   268.614701
# 2014-09  -396.386668
# 2014-10          NaN
# 2014-11         -inf
# 2014-12         -inf
# 2015-01         -inf
# 2015-02  -745.001123
# 2015-03  -411.520837
# 2015-04   -55.868905
# 2015-05  -290.525766
# 2015-06  -600.028943
# 2015-07  -586.274627
# 2015-08          inf
# 2015-09          NaN
# 2015-10         -inf
# 2015-11         -inf
# 2015-12         -inf
# 2016-01         -inf
# 2016-02          inf
# 2016-03          inf
# 2016-04          inf
# 2016-05          NaN
# 2016-06         -inf
# 2016-07         -inf
# 2016-08  -466.699781
# 2016-09  -666.441895
# 2016-10          NaN
# 2016-11         -inf
# 2016-12         -inf
# 2017-01         -inf
# 2017-02   320.066583
# 2017-03  -512.118676
# 2017-04          NaN
# 2017-05          inf
# 2017-06         -inf
# ...

# %%
table.plot(x ='yearmon', y = 'growth rate', kind = 'line')
plt.show()

# %%
#7)a.Create a new dataset including the product ids and total quantities sold for that id
sold_product = pd.DataFrame()
sold_product['Product id'] = data['Product ID']
sold_product['Sold quantities'] = data['Quantity']
sold_product
# Out:
#            Product id  Sold quantities
# 0     FUR-BO-10001798                2
# 1     FUR-CH-10000454                3
# 2     OFF-LA-10000240                2
# 3     FUR-TA-10000577                5
# 4     OFF-ST-10000760                2
# ...               ...              ...
# 9989  FUR-FU-10001889                3
# 9990  FUR-FU-10000747                2
# 9991  TEC-PH-10003645                2
# 9992  OFF-PA-10004041                4
# 9993  OFF-AP-10002684                2
#
# [9994 rows x 2 columns]

# %%
#7)b.Find out the most sold product from the created dataset
sold_product.max()
# Out:
# Product id         TEC-PH-10004977
# Sold quantities                 14
# dtype: object

# %%
#8)a.Create a dataset containing name and quantities bought
name_quantity = pd.DataFrame()
name_quantity['Name'] = data['Customer Name']
name_quantity['Quantities Bought'] = data['Quantity']
name_quantity
# Out:
#                   Name  Quantities Bought
# 0          Claire Gute                  2
# 1          Claire Gute                  3
# 2      Darrin Van Huff                  2
# 3       Sean O'Donnell                  5
# 4       Sean O'Donnell                  2
# ...                ...                ...
# 9989  Tom Boeckenhauer                  3
# 9990       Dave Brooks                  2
# 9991       Dave Brooks                  2
# 9992       Dave Brooks                  4
# 9993      Chris Cortes                  2
#
# [9994 rows x 2 columns]

# %%
#8)b.Find out the customer name and quantity, who bought maximum in quantity
name_quantity.max()
# Out:
# Name                 Zuschuss Donatelli
# Quantities Bought                    14
# dtype: object

# %%
#9)a.Create a dataset containing name and sales generated by him
name_sales = pd.DataFrame()
name_sales['Name'] = data['Customer Name']
name_sales['Sale value'] = data['Sales']
name_sales
# Out:
#                   Name  Sale value
# 0          Claire Gute    261.9600
# 1          Claire Gute    731.9400
# 2      Darrin Van Huff     14.6200
# 3       Sean O'Donnell    957.5775
# 4       Sean O'Donnell     22.3680
# ...                ...         ...
# 9989  Tom Boeckenhauer     25.2480
# 9990       Dave Brooks     91.9600
# 9991       Dave Brooks    258.5760
# 9992       Dave Brooks     29.6000
# 9993      Chris Cortes    243.1600
#
# [9994 rows x 2 columns]

# %%
customer = pd.DataFrame(name_sales,  columns =['Name', 'Sale value']) 
customer.set_index('Name', inplace = True) 
result = customer.loc["Zuschuss Donatelli"] 
result
# Out:
#                     Sale value
# Name
# Zuschuss Donatelli       8.560
# Zuschuss Donatelli     213.480
# Zuschuss Donatelli      22.720
# Zuschuss Donatelli      16.720
# Zuschuss Donatelli     823.960
# Zuschuss Donatelli      15.984
# Zuschuss Donatelli      71.120
# Zuschuss Donatelli     259.960
# Zuschuss Donatelli      61.440

# %%
#9)b.Find out the customer name and sales, who bought maximum in value
customer.max()
# Out:
# Sale value    22638.48
# dtype: float64

# %%
#10)Finding out the majority and minority customer cities on basis of 
#c. Number of quantity sold
city_quantity = pd.DataFrame()
city_quantity['City'] = data['City']
city_quantity['Quantity sold'] = data['Quantity']
city_quantity
# Out:
#                  City  Quantity sold
# 0           Henderson              2
# 1           Henderson              3
# 2         Los Angeles              2
# 3     Fort Lauderdale              5
# 4     Fort Lauderdale              2
# ...               ...            ...
# 9989            Miami              3
# 9990       Costa Mesa              2
# 9991       Costa Mesa              2
# 9992       Costa Mesa              4
# 9993      Westminster              2
#
# [9994 rows x 2 columns]

# %%
city_quantity.max()
# Out:
# City             Yuma
# Quantity sold      14
# dtype: object

# %%
city_quantity.min()
# Out:
# City             Aberdeen
# Quantity sold           1
# dtype: object

# %%
#10)Finding out the majority and minority customer cities on basis of 
#b. Sales value
city_sales = pd.DataFrame()
city_sales['City'] = data['City']
city_sales['Sale value'] = data['Sales']
city_sales
# Out:
#                  City  Sale value
# 0           Henderson    261.9600
# 1           Henderson    731.9400
# 2         Los Angeles     14.6200
# 3     Fort Lauderdale    957.5775
# 4     Fort Lauderdale     22.3680
# ...               ...         ...
# 9989            Miami     25.2480
# 9990       Costa Mesa     91.9600
# 9991       Costa Mesa    258.5760
# 9992       Costa Mesa     29.6000
# 9993      Westminster    243.1600
#
# [9994 rows x 2 columns]

# %%
city_sales.max()
# Out:
# City             Yuma
# Sale value    22638.5
# dtype: object

# %%
city_sales.min()
# Out:
# City          Aberdeen
# Sale value       0.444
# dtype: object

# %%
#10)Finding out the majority and minority customer cities on basis of 
#a. number of customers
city_customer = pd.DataFrame()
city_customer['City'] = data['City']
city_customer['Customers'] = data['Customer Name']
city_customer
city_customer.groupby(['City'])
print(city_customer)
# Out:
#                  City         Customers
# 0           Henderson       Claire Gute
# 1           Henderson       Claire Gute
# 2         Los Angeles   Darrin Van Huff
# 3     Fort Lauderdale    Sean O'Donnell
# 4     Fort Lauderdale    Sean O'Donnell
# ...               ...               ...
# 9989            Miami  Tom Boeckenhauer
# 9990       Costa Mesa       Dave Brooks
# 9991       Costa Mesa       Dave Brooks
# 9992       Costa Mesa       Dave Brooks
# 9993      Westminster      Chris Cortes
#
# [9994 rows x 2 columns]

# %%
city_customer.max()
# Out:
# City                       Yuma
# Customers    Zuschuss Donatelli
# dtype: object

# %%
city_customer.min()
# Out:
# City              Aberdeen
# Customers    Aaron Bergman
# dtype: object

# %%
#11)Find out the most and least sold product category from the store
#a.Value based
category_quantity1 = pd.DataFrame()
category_quantity1['Category name'] = data['Category']
category_quantity1['sales value'] = data['Sales']
category_quantity1
# Out:
#         Category name  sales value
# 0           Furniture     261.9600
# 1           Furniture     731.9400
# 2     Office Supplies      14.6200
# 3           Furniture     957.5775
# 4     Office Supplies      22.3680
# ...               ...          ...
# 9989        Furniture      25.2480
# 9990        Furniture      91.9600
# 9991       Technology     258.5760
# 9992  Office Supplies      29.6000
# 9993  Office Supplies     243.1600
#
# [9994 rows x 2 columns]

# %%
category_quantity1.max()
# Out:
# Category name    Technology
# sales value         22638.5
# dtype: object

# %%
category_quantity1.min()
# Out:
# Category name    Furniture
# sales value          0.444
# dtype: object

# %%
#11)Find out the most and least sold product category from the store
#b.Quantity based
category_quantity2 = pd.DataFrame()
category_quantity2['Category name'] = data['Category']
category_quantity2['quantity'] = data['Quantity']
category_quantity2
# Out:
#         Category name  quantity
# 0           Furniture         2
# 1           Furniture         3
# 2     Office Supplies         2
# 3           Furniture         5
# 4     Office Supplies         2
# ...               ...       ...
# 9989        Furniture         3
# 9990        Furniture         2
# 9991       Technology         2
# 9992  Office Supplies         4
# 9993  Office Supplies         2
#
# [9994 rows x 2 columns]

# %%
category_quantity.max()
# Out:
# Category name    Technology
# quantity                 14
# dtype: object

# %%
category_quantity.min()
# Out:
# Category name    Furniture
# quantity                 1
# dtype: object

# %%
#12)Find out the most and least sold product sub category from the store
#a.Value based
subcategory_quantity1 = pd.DataFrame()
subcategory_quantity1['Sub-Category name'] = data['Sub-Category']
subcategory_quantity1['Sale values'] = data['Sales']
subcategory_quantity1
# Out:
#      Sub-Category name  Sale values
# 0            Bookcases     261.9600
# 1               Chairs     731.9400
# 2               Labels      14.6200
# 3               Tables     957.5775
# 4              Storage      22.3680
# ...                ...          ...
# 9989       Furnishings      25.2480
# 9990       Furnishings      91.9600
# 9991            Phones     258.5760
# 9992             Paper      29.6000
# 9993        Appliances     243.1600
#
# [9994 rows x 2 columns]

# %%
subcategory_quantity1.max()
# Out:
# Sub-Category name     Tables
# Sale values          22638.5
# dtype: object

# %%
subcategory_quantity1.min()
# Out:
# Sub-Category name    Accessories
# Sale values                0.444
# dtype: object

# %%
#12)Find out the most and least sold product sub category from the store
#b.Quantity based
subcategory_quantity2 = pd.DataFrame()
subcategory_quantity2['Sub-Category name'] = data['Sub-Category']
subcategory_quantity2['quantity'] = data['Quantity']
subcategory_quantity2
# Out:
#      Sub-Category name  quantity
# 0            Bookcases         2
# 1               Chairs         3
# 2               Labels         2
# 3               Tables         5
# 4              Storage         2
# ...                ...       ...
# 9989       Furnishings         3
# 9990       Furnishings         2
# 9991            Phones         2
# 9992             Paper         4
# 9993        Appliances         2
#
# [9994 rows x 2 columns]

# %%
subcategory_quantity2.max()
# Out:
# Sub-Category name    Tables
# quantity                 14
# dtype: object

# %%
subcategory_quantity2.min()
# Out:
# Sub-Category name    Accessories
# quantity                       1
# dtype: object
