# %%
#1)a
import pandas as pd
import numpy as np

#2)
#a.
data = pd.read_csv("Superstore.xls - Orders.csv")
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#b.
data.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#c.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#d.
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#e.
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#3)
#a.
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data['Order Date'] = pd.to_datetime(data['Order Date'])
idata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#b.
data['price per unit'] = data['Sales'] / data['Quantity']
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data['Ship Date'].unique()
#2016,2015,2014,2017
# Out:
# array(['2016-11-11T00:00:00.000000000', '2016-06-16T00:00:00.000000000',
#        '2015-10-18T00:00:00.000000000', ...,
#        '2015-05-23T00:00:00.000000000', '2014-01-23T00:00:00.000000000',
#        '2017-03-03T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
data['Order Date'].unique()
#2016,2015,2014
# Out:
# array(['2016-11-08T00:00:00.000000000', '2016-06-12T00:00:00.000000000',
#        '2015-10-11T00:00:00.000000000', ...,
#        '2016-06-03T00:00:00.000000000', '2015-04-12T00:00:00.000000000',
#        '2014-01-21T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
price_quantity = pd.DataFrame(data['Product ID'],data['Quantity'])
price_quantity

# %%
#7)
#a.
price_quantity = pd.DataFrame(data['Product ID'],data['Quantity'])
price_quantity
# Out:
#                Product ID
# Quantity
# 2         OFF-LA-10000240
# 3         FUR-TA-10000577
# 2         OFF-LA-10000240
# 5         FUR-FU-10001487
# 2         OFF-LA-10000240
# ...                   ...
# 3         FUR-TA-10000577
# 2         OFF-LA-10000240
# 2         OFF-LA-10000240
# 4         OFF-ST-10000760
# 2         OFF-LA-10000240
#
# [9994 rows x 1 columns]

# %%
price_quantity.groupby(data['Product ID']).sum().sort_values(data['Quantity'], ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-dcd1dd80bd59> in <module>
# ----> 1 price_quantity.groupby(data['Product ID']).sum().sort_values(data['Quantity'], ascending=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 0       2
# 1       3
# ...

# %%
data['Product ID'].unique()
# Out:
# array(['FUR-BO-10001798', 'FUR-CH-10000454', 'OFF-LA-10000240', ...,
#        'OFF-AP-10003099', 'TEC-PH-10002645', 'OFF-ST-10001627'],
#       dtype=object)

# %%
data['Product ID'].value_counts()
# Out:
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10002647    15
# TEC-AC-10003628    15
#                    ..
# OFF-ST-10001414     1
# TEC-AC-10002380     1
# TEC-AC-10004814     1
# TEC-MA-10000112     1
# OFF-ST-10001034     1
# Name: Product ID, Length: 1862, dtype: int64

# %%
data['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12])

# %%
data['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %%
data['Product ID'].value_counts()
# Out:
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10002647    15
# TEC-AC-10003628    15
#                    ..
# OFF-ST-10001414     1
# TEC-AC-10002380     1
# TEC-AC-10004814     1
# TEC-MA-10000112     1
# OFF-ST-10001034     1
# Name: Product ID, Length: 1862, dtype: int64

# %%
product_ID = ('0240', '0577', '1487',
       '2275', '0760', '2833',
       '2892', '0454', '3910',
       '2311', '2033', '3656',
       '1539', '2365')
quantity = (2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12)
# Out:
# 105

# %%
import matplotlib.pyplot as plt
plt.bar(product_ID, quantity, color = 'Blue')
plt.bar(product_ID, quantity, color = 'Blue',linewidth=10,linestyle='dashed')
plt.xlabel("condition of house")
plt.ylabel("count of house")
plt.title("graph")
plt.show()

# %%
#8)
#a.
name_quantity = pd.DataFrame(data['Customer Name'],data['Quantity'])
name_quantity
# Out:
#             Customer Name
# Quantity
# 2         Darrin Van Huff
# 3          Sean O'Donnell
# 2         Darrin Van Huff
# 5         Brosina Hoffman
# 2         Darrin Van Huff
# ...                   ...
# 3          Sean O'Donnell
# 2         Darrin Van Huff
# 2         Darrin Van Huff
# 4          Sean O'Donnell
# 2         Darrin Van Huff
#
# [9994 rows x 1 columns]

# %%
#9)
#a.
name_sales = pd.DataFrame(data['Customer Name'],data['Sales'])
name_sales
